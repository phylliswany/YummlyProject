# %%
import numpy as np

# %% [markdown]
# Read the training data set

# %%
X = np.load('TrainingDataX.npy')
y = np.load('TrainingDatay.npy')
# print X_train
# print y_train
# Out:
# [17 67 83 ..., 17 17 83]

# %%
import copy

# %%
def FlavorClass(z):
    x = []
    for y in z:
        if y <= 17:
            x.append(0)
        elif y >= 83:
            x.append(2)
        else:
            x.append(1)
    # print z[0]
    # print x[0]
    x = np.array(x)
    return x

# %% [markdown]
# Test the model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import KFold
import matplotlib.pyplot as plt

# %% [markdown]
# RandomForest for salty (100 is the best)

# %%
n_trees = 10
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.40343502731
# 0.521410424152

# %%
n_trees = 30
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.43395291202
# 0.541515925595

# %%
n_trees = 50
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.440282998622
# 0.542264958152

# %%
n_trees = 80
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.437678691339
# 0.539287519124

# %%
n_trees = 100
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.443261822184
# 0.546734231895

# %%
n_trees = 120
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.445490228656
# 0.544867188636

# %%
n_trees = 150
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.441024416246
# 0.541516617862

# %%
n_trees = 200
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.44251417416
# 0.541887672807

# %%
n_trees = 300
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 0
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.446235107613
# 0.541887672807

# %% [markdown]
# 1oo trees for savory

# %%
n_trees = 100
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 1
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.455892920189
# 0.518795732868

# %% [markdown]
# 100 trees for sour

# %%
n_trees = 100
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 2
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.554522232145
# 0.637147030522

# %% [markdown]
# 100 trees for bitter

# %%
n_trees = 100
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 3
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.490144199151
# 0.538157739888

# %% [markdown]
# 100 trees for sweet

# %%
n_trees = 100
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 4
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.60438620174
# 0.688871120711

# %% [markdown]
# 100 trees for spicy

# %%
n_trees = 100
kf = KFold(np.shape(X)[0], n_folds=5)
forest = RandomForestClassifier(n_estimators = n_trees, random_state = 1)
column = 5
accuracy = []
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index, column], y[test_index, column]
    
    forest.fit(X_train, y_train)
    y_hat = forest.predict(X_test)
    
    accuracy.append([n_trees, float(sum(y_hat == y_test))/len(y_test), float(sum(FlavorClass(y_hat) == FlavorClass(y_test)))/len(y_test)])
    
# %matplotlib notebook
plt.plot([x[1] for x in accuracy])
plt.plot([x[2] for x in accuracy])
print np.mean([x[1] for x in accuracy])
print np.mean([x[2] for x in accuracy])
# Out:
# <img src="data:image/png;base64,...">
# 0.811685461707
# 0.890583788499
